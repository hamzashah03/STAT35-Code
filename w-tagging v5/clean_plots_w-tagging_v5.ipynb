# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from sklearn.metrics import roc_curve
from matplotlib.ticker import MaxNLocator
import dcor

# %% [markdown]
# # CATHODE, CDOT, LaCATHODE Plots Production
#
# This jupyter notebook reads in the data produced from the "data production" jupyter notebook and produces useful plots using it.

# %% [markdown]
# # Importing Data

# %%
train_df = pd.read_pickle("./train.pkl")

val_df = pd.read_pickle("./val.pkl")

test_df = pd.read_pickle("./test.pkl")

cathode_samples_df = pd.read_pickle("./cathode_samples.pkl")

latent_train_df = pd.read_pickle("./LaCATHODE_train.pkl")

latent_sample_df = pd.read_pickle("./LaCATHODE_samples.pkl")

# %% [markdown]
# # Intro Sculpting Plot

# %%
fig, axs = plt.subplots(1, 2, figsize = (20,5))

bins = np.linspace(0, 1, 71)  # 51 edges = 50 bins

for ax in axs.flatten():
    ax.yaxis.set_major_locator(MaxNLocator(4))

axs[0].hist(test_df[test_df["signal"]==1]["mass"],
            bins = bins,
            label = "Signal",
            histtype = "stepfilled",
            color = "orange",
            edgecolor = "darkorange",
            alpha = 0.8,
            linewidth = 1.5,
            density = True)

axs[0].hist(test_df[test_df["signal"]==0]["mass"],
            bins = bins,
            label = "Background",
            histtype = "stepfilled",
            color = "slateblue",
            edgecolor = "slateblue",
            alpha = 0.5,
            linewidth = 1.5,
            density = True
            )

leg_0 = axs[0].legend(prop = {'size': 16})
title0 = leg_0.get_title()
title0.set_fontsize(10)
title0.set_fontweight('bold')
title0.set_position((-42.5, 0))

axs[0].set_xlabel("Invariant Mass", fontsize = 15)
axs[0].set_ylabel("Density", fontsize = 15)
axs[0].set_title("Density of Mass")

cutdata = test_df[test_df["ideal_h"] > np.quantile(test_df["ideal_h"], 0.85)]

axs[1].hist(cutdata[cutdata["signal"]==1]["mass"],
            bins = bins,
            label = "Signal",
            histtype = "stepfilled",
            color = "orange",
            edgecolor = "darkorange",
            alpha = 0.8,
            linewidth = 1.5,
            density = True)



axs[1].hist(cutdata[cutdata["signal"]==0]["mass"],
            bins = bins,
            label = "Background",
            histtype = "stepfilled",
            color = "slateblue",
            edgecolor = "slateblue",
            alpha = 0.5,
            linewidth = 1.5,
            density = True
            )


leg_1 = axs[1].legend(prop={'size': 16})
title1 = leg_1.get_title()
title1.set_fontweight('bold')
title1.set_position((-42.5, 0))

axs[1].set_xlabel("Invariant Mass", fontsize = 15)
axs[1].set_ylabel("Density", fontsize = 15)
axs[1].set_title("Density of Mass given $h > F^{-1}_h(0.85)$")

fig.savefig('Problem:Sculpting_Presentation.png', bbox_inches='tight')

plt.show()

# %%
fig, axs = plt.subplots(1, 2, figsize = (20,5))

bins = np.linspace(0, 1, 71)  # 51 edges = 50 bins

for ax in axs.flatten():
    ax.yaxis.set_major_locator(MaxNLocator(4))

axs[0].hist(test_df[test_df["signal"]==1]["mass"],
            bins = bins,
            label = "Signal",
            histtype = "stepfilled",
            color = "orange",
            edgecolor = "darkorange",
            alpha = 0.8,
            linewidth = 1.5,
            density = True)

axs[0].hist(test_df[test_df["signal"]==0]["mass"],
            bins = bins,
            label = "Background",
            histtype = "stepfilled",
            color = "slateblue",
            edgecolor = "slateblue",
            alpha = 0.5,
            linewidth = 1.5,
            density = True
            )

leg_0 = axs[0].legend(prop = {'size': 16})
title0 = leg_0.get_title()
title0.set_fontsize(10)
title0.set_fontweight('bold')
title0.set_position((-42.5, 0))

axs[0].set_xlabel("Invariant Mass", fontsize = 15)
axs[0].set_ylabel("Density", fontsize = 15)
axs[0].set_title("Density of Mass")

cutdata = test_df[test_df["trans_ideal_h"] > np.quantile(test_df["trans_ideal_h"], 0.85)]

axs[1].hist(cutdata[cutdata["signal"]==1]["mass"],
            bins = bins,
            label = "Signal",
            histtype = "stepfilled",
            color = "orange",
            edgecolor = "darkorange",
            alpha = 0.8,
            linewidth = 1.5,
            density = True)



axs[1].hist(cutdata[cutdata["signal"]==0]["mass"],
            bins = bins,
            label = "Background",
            histtype = "stepfilled",
            color = "slateblue",
            edgecolor = "slateblue",
            alpha = 0.5,
            linewidth = 1.5,
            density = True
            )

leg_1 = axs[1].legend(prop={'size': 16})
title1 = leg_1.get_title()
title1.set_fontweight('bold')
title1.set_position((-42.5, 0))

axs[1].set_xlabel("Invariant Mass", fontsize = 15)
axs[1].set_ylabel("Density", fontsize = 15)
axs[1].set_title("Density of Mass given $T(h) > F^{-1}_h(0.85)$")

fig.savefig('Solution:Decorrelation_Presentation.png', bbox_inches='tight')

plt.show()

# %%
fig, axs = plt.subplots(1, 2, figsize = (12,5))

bins = np.linspace(0, 1, 71)  # 51 edges = 50 bins

for ax in axs.flatten():
    ax.yaxis.set_major_locator(MaxNLocator(4))

axs[0].hist(test_df[test_df["signal"]==1]["mass"],
            bins = bins,
            label = "Signal",
            histtype = "stepfilled",
            color = "orange",
            edgecolor = "darkorange",
            alpha = 0.8,
            linewidth = 1.5,
            density = True)

axs[0].hist(test_df[test_df["signal"]==0]["mass"],
            bins = bins,
            label = "Background",
            histtype = "stepfilled",
            color = "slateblue",
            edgecolor = "slateblue",
            alpha = 0.5,
            linewidth = 1.5,
            density = True
            )

leg_0 = axs[0].legend(prop = {'size': 16})
title0 = leg_0.get_title()
title0.set_fontsize(10)
title0.set_fontweight('bold')
title0.set_position((-42.5, 0))

axs[0].set_xlabel("Protected Variable", fontsize = 15)
axs[0].set_ylabel("Density", fontsize = 15)
axs[0].set_title("Density of Mass")

cutdata = test_df[test_df["ideal_h"] > np.quantile(test_df["ideal_h"], 0.85)]

axs[1].hist(cutdata[cutdata["signal"]==1]["mass"],
            bins = bins,
            label = "Signal",
            histtype = "stepfilled",
            color = "orange",
            edgecolor = "darkorange",
            alpha = 0.8,
            linewidth = 1.5,
            density = True)



axs[1].hist(cutdata[cutdata["signal"]==0]["mass"],
            bins = bins,
            label = "Background",
            histtype = "stepfilled",
            color = "slateblue",
            edgecolor = "slateblue",
            alpha = 0.5,
            linewidth = 1.5,
            density = True
            )


leg_1 = axs[1].legend(prop={'size': 16})
title1 = leg_1.get_title()
title1.set_fontweight('bold')
title1.set_position((-42.5, 0))

axs[1].set_xlabel("Protected Variable", fontsize = 15)
axs[1].set_ylabel("Density", fontsize = 15)
axs[1].set_title("Density of Mass given $h > F^{-1}_h(0.85)$")

fig.savefig('Sculpting_Intro.png', bbox_inches='tight')

plt.show()

# %%
fig, axs = plt.subplots(1, 1, figsize = (10,5))

bins = np.linspace(0, 1, 71)  # 51 edges = 50 bins

axs.yaxis.set_major_locator(MaxNLocator(4))

axs.hist(test_df[test_df["signal"]==1]["mass"],
            bins = bins,
            label = "Signal",
            histtype = "stepfilled",
            color = "orange",
            edgecolor = "darkorange",
            alpha = 0.8,
            linewidth = 1.5,
            density = True)

axs.hist(test_df[test_df["signal"]==0]["mass"],
            bins = bins,
            label = "Background",
            histtype = "stepfilled",
            color = "slateblue",
            edgecolor = "slateblue",
            alpha = 0.5,
            linewidth = 1.5,
            density = True
            )

axs.axvline(x=0.0760924, linestyle=":", color="black", linewidth=2)
axs.axvline(x=0.1923158, linestyle=":", color="black", linewidth=2)

leg_0 = axs.legend(prop = {'size': 16})
title0 = leg_0.get_title()
title0.set_fontsize(10)
title0.set_fontweight('bold')
title0.set_position((-42.5, 0))

axs.set_xlabel("Invariant Mass", fontsize = 15)
axs.set_ylabel("Density", fontsize = 15)

fig.savefig('Pres_W-tagging_Data.png', bbox_inches='tight')

plt.show()

# %%
# fig, axs = plt.subplots(1, 2, figsize = (12,5))

# bins = np.linspace(0, 1, 71)  # 51 edges = 50 bins

# for ax in axs.flatten():
#     ax.yaxis.set_major_locator(MaxNLocator(4))

# axs[0].hist(test_df[test_df["signal"]==1]["mass"],
#             bins = bins,
#             label = "Signal",
#             color = "orange",
#             edgecolor = "darkorange",
#             alpha = 0.8,
#             linewidth = 1.5,
#             density = True)

# axs[0].hist(test_df[test_df["signal"]==0]["mass"],
#             bins = bins,
#             label = "Background",
#             color = "slateblue",
#             edgecolor = "slateblue",
#             alpha = 0.5,
#             linewidth = 1.5,
#             density = True
#             )

# leg_0 = axs[0].legend(prop = {'size': 16})
# title0 = leg_0.get_title()
# title0.set_fontsize(10)
# title0.set_fontweight('bold')
# title0.set_position((-42.5, 0))

# axs[0].set_xlabel("Protected Variable", fontsize = 15)
# axs[0].set_ylabel("Density", fontsize = 15)

# cutdata = test_df[test_df["ideal_h"] > np.quantile(test_df["ideal_h"], 0.85)]

# axs[1].hist(cutdata[cutdata["signal"]==1]["mass"],
#             bins = bins,
#             label = "Signal",
#             color = "orange",
#             edgecolor = "darkorange",
#             alpha = 0.8,
#             linewidth = 1.5,
#             density = True)



# axs[1].hist(cutdata[cutdata["signal"]==0]["mass"],
#             bins = bins,
#             label = "Background",
#             color = "slateblue",
#             edgecolor = "slateblue",
#             alpha = 0.5,
#             linewidth = 1.5,
#             density = True
#             )


# leg_1 = axs[1].legend(prop={'size': 16})
# title1 = leg_1.get_title()
# title1.set_fontweight('bold')
# title1.set_position((-42.5, 0))

# axs[1].set_xlabel("Protected Variable", fontsize = 15)
# axs[1].set_ylabel("Density", fontsize = 15)

# fig.savefig('Sculpting_Intro.png', bbox_inches='tight')

# plt.show()

# %% [markdown]
# # First Set of Cut Plots

# %%
# # Assign which classifier output you want to use
# h = ("h", "trans_h", "inv_trans_h", "la_h", "no_cut")     # Pre-CDOT classifier output

# titles = (r"$h_{CATHODE}$", r"$T_M(h_{CATHODE})$", r"$T_M(h_{CATHODE})$", r"$h_{LaCATHODE}$", "No Cut")

# fig, axs = plt.subplots(2, 5, figsize = (25,12))

# bins = np.linspace(0, 1, 51)  # 51 edges = 50 bins

# # for ax in axs.flatten():                                  # Uncomment to show numbers across all the y-axes
# #     ax.tick_params(labelbottom=True, labelleft=True)


# for ax in axs.flatten():
#     ax.yaxis.set_major_locator(MaxNLocator(5))

# thresh = 0.85

# density_flag = (True, False)

# y_label = ["Density", "Counts"]

# # y-axis label
# axs[0,0].set_ylabel("Density")
# axs[1,0].set_ylabel("Counts")

# for i in range(axs.shape[0]):
#     # Assign the plot to be a density plot or a histogram
#     density = density_flag[i]
#     for j in range(axs.shape[1]):

#         # Set the range of classifier outputs accepted for the plot
#         if h[j] != "no_cut":
#             cutdata = test_df[(test_df[h[j]] >= np.quantile(test_df[h[j]], thresh))]
#         else:
#             cutdata = test_df


#         n, bins, patches = axs[i,j].hist(
#             cutdata[cutdata["signal"] == 1]["mass"],
#             bins = bins,
#             label = "Signal",
#             color = "orange",
#             edgecolor = "darkorange",
#             alpha = 0.8,
#             linewidth = 1.5,
#             density = density)
        
#         # for patch in patches:
#         #     patch.set_edgecolor((0, 0, 1, 1))  # RGBA - last value is alpha (1 = fully opaque)

        
#         n, bins, patches = axs[i,j].hist(
#             cutdata[cutdata["signal"] == 0]["mass"],
#             bins = bins,
#             label = "Background",
#             color = "slateblue",
#             edgecolor = "slateblue",
#             alpha = 0.5,
#             linewidth = 1.5,
#             density = density)
        
#         # for patch in patches:
#         #     patch.set_edgecolor((1, 0, 0, 1))  # RGBA - last value is alpha (1 = fully opaque)


        
#         axs[i,j].set_xlabel("Mass")
#         axs[i,j].set_title(titles[j])

#         axs[i,j].axvline(x=0.0760924, linestyle=":", color="black", linewidth=2)
#         axs[i,j].axvline(x=0.1923158, linestyle=":", color="black", linewidth=2)

# # share y-axis only across first row
# for ax in axs[0, 1:]:
#     ax.sharey(axs[0, 0])

# h, l = axs[0,0].get_legend_handles_labels()     # Avoid repeats of legend, labels from 1st plot

# fig.legend(h, l, loc="lower center", ncol = 2, prop={'size': 15})

# # fig.savefig()

# plt.show()

# %%
# # Assign which classifier output you want to use
# h = ("h", "trans_h", "inv_trans_h", "la_h", "no_cut")     # Pre-CDOT classifier output

# titles = (r"$h_{CATHODE}$", r"$T_M(h_{CATHODE})$", r"$T_M(h_{CATHODE})$", r"$h_{LaCATHODE}$", "No Cut")

# fig, axs = plt.subplots(2, 5, figsize = (25,12))

# bins = np.linspace(0, 1, 51)  # 51 edges = 50 bins

# # for ax in axs.flatten():                                  # Uncomment to show numbers across all the y-axes
# #     ax.tick_params(labelbottom=True, labelleft=True)


# for ax in axs.flatten():
#     ax.yaxis.set_major_locator(MaxNLocator(5))

# thresh = 0.85

# density_flag = (True, False)

# y_label = ["Density", "Counts"]

# # y-axis label
# axs[0,0].set_ylabel("Density")
# axs[1,0].set_ylabel("Counts")

# for i in range(axs.shape[0]):
#     # Assign the plot to be a density plot or a histogram
#     density = density_flag[i]
#     for j in range(axs.shape[1]):

#         # Set the range of classifier outputs accepted for the plot
#         if h[j] != "no_cut":
#             cutdata = test_df[(test_df[h[j]] >= np.quantile(test_df[h[j]], thresh))]
#         else:
#             cutdata = test_df

        
#         n, bins, patches = axs[i,j].hist(
#             cutdata[cutdata["signal"] == 0]["mass"],
#             bins = bins,
#             label = "Background",
#             color = "blue",
#             edgecolor = "blue",
#             alpha = 0.4,
#             linewidth = 1.5,
#             density = density)
        
#         # for patch in patches:
#         #     patch.set_edgecolor((1, 0, 0, 1))  # RGBA - last value is alpha (1 = fully opaque)

#         n, bins, patches = axs[i,j].hist(
#             cutdata[cutdata["signal"] == 1]["mass"],
#             bins = bins,
#             label = "Signal",
#             color = "orange",
#             edgecolor = "orange",
#             alpha = 0.6,
#             linewidth = 1.5,
#             density = density)
        
#         # for patch in patches:
#         #     patch.set_edgecolor((0, 0, 1, 1))  # RGBA - last value is alpha (1 = fully opaque)



        
#         axs[i,j].set_xlabel("Mass")
#         axs[i,j].set_title(titles[j])

#         axs[i,j].axvline(x=0.0760924, linestyle=":", color="black", linewidth=2)
#         axs[i,j].axvline(x=0.1923158, linestyle=":", color="black", linewidth=2)

# # share y-axis only across first row
# for ax in axs[0, 1:]:
#     ax.sharey(axs[0, 0])

# h, l = axs[0,0].get_legend_handles_labels()     # Avoid repeats of legend, labels from 1st plot

# fig.legend(h, l, loc="lower center", ncol = 2, prop={'size': 15})

# # fig.savefig()

# plt.show()

# %%
# Assign which classifier output you want to use
h = ("no_cut", "h", "trans_h", "la_h")     # Pre-CDOT classifier output

titles = ("No Cut", r"$\mathbf{h_{CATHODE}}$", r"$\mathbf{T_M(h_{CATHODE})}$", r"$\mathbf{h_{LaCATHODE}}$")

fig, axs = plt.subplots(2, len(h), figsize = (30,15))

bins = np.linspace(0, 1, 71)  # 51 edges = 50 bins

# for ax in axs.flatten():                                  # Uncomment to show numbers across all the y-axes
#     ax.tick_params(labelbottom=True, labelleft=True)


for ax in axs.flatten():
    ax.yaxis.set_major_locator(MaxNLocator(5))

thresh = 0.85

density_flag = (True, False)

y_label = ["Density", "Counts"]

# y-axis label
axs[0,0].set_ylabel("Density", fontsize = 31)
axs[1,0].set_ylabel("Counts", fontsize = 31)

for i in range(axs.shape[0]):
    # Assign the plot to be a density plot or a histogram
    density = density_flag[i]
    for j in range(axs.shape[1]):

        # Set the range of classifier outputs accepted for the plot
        if h[j] != "no_cut":
            cutdata = test_df[(test_df[h[j]] >= np.quantile(test_df[h[j]], thresh))]
        else:
            cutdata = test_df

        axs[i,j].hist(cutdata[cutdata["signal"]==1]["mass"],
            bins = bins,
            label = "Signal",
            histtype = "stepfilled",
            color = "orange",
            edgecolor = "darkorange",
            alpha = 0.8,
            linewidth = 1.5,
            density = density)
        
        axs[i,j].hist(cutdata[cutdata["signal"]==0]["mass"],
            bins = bins,
            label = "Background",
            histtype = "stepfilled",
            color = "slateblue",
            edgecolor = "slateblue",
            alpha = 0.5,
            linewidth = 1.5,
            density = density
            )
        
        # Axis numbers font size
        axs[i,j].tick_params(axis='x', labelsize=21)
        axs[i,j].tick_params(axis='y', labelsize=21)

        # Axis Label font size
        axs[i,j].set_xlabel("Mass", fontsize = 31)
        axs[i,j].set_title(titles[j], fontsize = 31, fontweight = "bold")

        axs[i,j].axvline(x=0.0760924, linestyle=":", color="black", linewidth=2)
        axs[i,j].axvline(x=0.1923158, linestyle=":", color="black", linewidth=2)

        lambda_hat = len(cutdata[cutdata["signal"]==1]) / len(cutdata[cutdata["signal"]==0])

        print(f"{h[j]}: Signal-to-Backgound ratio {lambda_hat}")

# share y-axis only across first row
for ax in axs[0, 1:]:
    ax.sharey(axs[0, 0])

h, l = axs[0,0].get_legend_handles_labels()     # Avoid repeats of legend, labels from 1st plot

fig.legend(h, l, loc="lower center", ncol = 2, prop={'size': 25}, bbox_to_anchor=(0.5, 0))

# Vertical Space between the subplots
fig.subplots_adjust(hspace=0.275)

fig.savefig('Unsupervised_Cuts_W-tagging.png', bbox_inches='tight')

plt.show()
# Out:
# no_cut: Signal-to-Backgound ratio 0.1038961038961039
# h: Signal-to-Backgound ratio 0.27256939246040063
# trans_h: Signal-to-Backgound ratio 0.38169444504648997
# la_h: Signal-to-Backgound ratio 0.3094382253260758
# no_cut: Signal-to-Backgound ratio 0.1038961038961039
# h: Signal-to-Backgound ratio 0.27256939246040063
# trans_h: Signal-to-Backgound ratio 0.38169444504648997
# la_h: Signal-to-Backgound ratio 0.3094382253260758

# %%
# Assign which classifier output you want to use
h = ("no_cut", "h", "trans_h", "la_h")     # Pre-CDOT classifier output

titles = ("No Cut", r"$\mathbf{h_{CATHODE}}$", r"$\mathbf{T_M(h_{CATHODE})}$", r"$\mathbf{h_{LaCATHODE}}$")

fig, axs = plt.subplots(2, len(h), figsize = (35,15))

bins = np.linspace(0, 1, 71)  # 51 edges = 50 bins

# for ax in axs.flatten():                                  # Uncomment to show numbers across all the y-axes
#     ax.tick_params(labelbottom=True, labelleft=True)


for ax in axs.flatten():
    ax.yaxis.set_major_locator(MaxNLocator(5))

thresh = 0.85

density_flag = (True, False)

y_label = ["Density", "Counts"]

# y-axis label
axs[0,0].set_ylabel("Density", fontsize = 31)
axs[1,0].set_ylabel("Counts", fontsize = 31)

for i in range(axs.shape[0]):
    # Assign the plot to be a density plot or a histogram
    density = density_flag[i]
    for j in range(axs.shape[1]):

        # Set the range of classifier outputs accepted for the plot
        if h[j] != "no_cut":
            cutdata = test_df[(test_df[h[j]] >= np.quantile(test_df[h[j]], thresh))]
        else:
            cutdata = test_df

        axs[i,j].hist(cutdata[cutdata["signal"]==1]["mass"],
            bins = bins,
            label = "Signal",
            histtype = "stepfilled",
            color = "orange",
            edgecolor = "darkorange",
            alpha = 0.8,
            linewidth = 1.5,
            density = density)
        
        axs[i,j].hist(cutdata[cutdata["signal"]==0]["mass"],
            bins = bins,
            label = "Background",
            histtype = "stepfilled",
            color = "slateblue",
            edgecolor = "slateblue",
            alpha = 0.5,
            linewidth = 1.5,
            density = density
            )
        
        # Axis numbers font size
        axs[i,j].tick_params(axis='x', labelsize=21)
        axs[i,j].tick_params(axis='y', labelsize=21)

        # Axis Label font size
        axs[i,j].set_xlabel("Mass", fontsize = 31)
        axs[i,j].set_title(titles[j], fontsize = 31, fontweight = "bold")

        axs[i,j].axvline(x=0.0760924, linestyle=":", color="black", linewidth=2)
        axs[i,j].axvline(x=0.1923158, linestyle=":", color="black", linewidth=2)

        lambda_hat = len(cutdata[cutdata["signal"]==1]) / len(cutdata[cutdata["signal"]==0])

        print(f"{h[j]}: Signal-to-Backgound ratio {lambda_hat}")

# share y-axis only across first row
for ax in axs[0, 1:]:
    ax.sharey(axs[0, 0])

h, l = axs[0,0].get_legend_handles_labels()     # Avoid repeats of legend, labels from 1st plot

fig.legend(h, l, loc="lower center", ncol = 2, prop={'size': 25}, bbox_to_anchor=(0.5, 0))

# Vertical Space between the subplots
fig.subplots_adjust(hspace=0.275)

fig.savefig('pres_Unsupervised_Cuts_W-tagging.png', bbox_inches='tight')

plt.show()
# Out:
# no_cut: Signal-to-Backgound ratio 0.1038961038961039
# h: Signal-to-Backgound ratio 0.27256939246040063
# trans_h: Signal-to-Backgound ratio 0.38169444504648997
# la_h: Signal-to-Backgound ratio 0.3094382253260758
# no_cut: Signal-to-Backgound ratio 0.1038961038961039
# h: Signal-to-Backgound ratio 0.27256939246040063
# trans_h: Signal-to-Backgound ratio 0.38169444504648997
# la_h: Signal-to-Backgound ratio 0.3094382253260758

# %%
# Assign which classifier output you want to use
h = ("no_cut", "ideal_h", "trans_ideal_h")     # Pre-CDOT classifier output

titles = ("No Cut", r"$\mathbf{h_{Supervised}}$", r"$\mathbf{T_M(h_{Supervised})}$")

fig, axs = plt.subplots(2, len(h), figsize = (30,15))

bins = np.linspace(0, 1, 71)  # 51 edges = 50 bins

# for ax in axs.flatten():                                  # Uncomment to show numbers across all the y-axes
#     ax.tick_params(labelbottom=True, labelleft=True)


for ax in axs.flatten():
    ax.yaxis.set_major_locator(MaxNLocator(5))

thresh = 0.85

density_flag = (True, False)

y_label = ["Density", "Counts"]

# y-axis label
axs[0,0].set_ylabel("Density", fontsize = 31)
axs[1,0].set_ylabel("Counts", fontsize = 31)

for i in range(axs.shape[0]):
    # Assign the plot to be a density plot or a histogram
    density = density_flag[i]
    for j in range(axs.shape[1]):

        # Set the range of classifier outputs accepted for the plot
        if h[j] != "no_cut":
            cutdata = test_df[(test_df[h[j]] >= np.quantile(test_df[h[j]], thresh))]
        else:
            cutdata = test_df

        axs[i,j].hist(cutdata[cutdata["signal"]==1]["mass"],
            bins = bins,
            label = "Signal",
            histtype = "stepfilled",
            color = "orange",
            edgecolor = "darkorange",
            alpha = 0.8,
            linewidth = 1.5,
            density = density)
        
        axs[i,j].hist(cutdata[cutdata["signal"]==0]["mass"],
            bins = bins,
            label = "Background",
            histtype = "stepfilled",
            color = "slateblue",
            edgecolor = "slateblue",
            alpha = 0.5,
            linewidth = 1.5,
            density = density
            )
        
        # Axis numbers font size
        axs[i,j].tick_params(axis='x', labelsize=21)
        axs[i,j].tick_params(axis='y', labelsize=21)

        # Axis Label font size
        axs[i,j].set_xlabel("Mass", fontsize = 31)
        axs[i,j].set_title(titles[j], fontsize = 31, fontweight = "bold")

        axs[i,j].axvline(x=0.0760924, linestyle=":", color="black", linewidth=2)
        axs[i,j].axvline(x=0.1923158, linestyle=":", color="black", linewidth=2)

        lambda_hat = len(cutdata[cutdata["signal"]==1]) / len(cutdata[cutdata["signal"]==0])

        print(f"{h[j]}: Signal-to-Backgound ratio {lambda_hat}")

# share y-axis only across first row
for ax in axs[0, 1:]:
    ax.sharey(axs[0, 0])

h, l = axs[0,0].get_legend_handles_labels()     # Avoid repeats of legend, labels from 1st plot

fig.legend(h, l, loc="lower center", ncol = 2, prop={'size': 25}, bbox_to_anchor=(0.5, 0))

# Vertical Space between the subplots
fig.subplots_adjust(hspace=0.275)

fig.savefig('Supervised_Cuts_W-tagging.png', bbox_inches='tight')

plt.show()
# Out:
# no_cut: Signal-to-Backgound ratio 0.1038961038961039
# ideal_h: Signal-to-Backgound ratio 0.7119379137183292
# trans_ideal_h: Signal-to-Backgound ratio 0.49616278251073714
# no_cut: Signal-to-Backgound ratio 0.1038961038961039
# ideal_h: Signal-to-Backgound ratio 0.7119379137183292
# trans_ideal_h: Signal-to-Backgound ratio 0.49616278251073714

# %%
with np.errstate(divide='ignore', invalid='ignore'):
    # Classifier Outputs (Pre-CDOT)
    h_fpr, h_tpr, _ = roc_curve(test_df["signal"], test_df["h"])
    h_sic = h_tpr / np.sqrt(h_fpr)

    print(len(_))

    # Transformed Classifier outputs (Post-CDOT)
    trans_h_fpr, trans_h_tpr, _ = roc_curve(test_df["signal"], test_df["trans_h"])
    trans_h_sic = trans_h_tpr / np.sqrt(trans_h_fpr)

    # Inverse Transformed Classifier outputs (Post-CDOT)
    inv_trans_h_fpr, inv_trans_h_tpr, _ = roc_curve(test_df["signal"], test_df["inv_trans_h"])
    inv_trans_h_sic = inv_trans_h_tpr / np.sqrt(inv_trans_h_fpr)

    # LaCATHODE classifier outputs
    la_h_fpr, la_h_tpr, _ = roc_curve(test_df[~np.isnan(test_df["la_h"])]["signal"], test_df[~np.isnan(test_df["la_h"])]["la_h"])
    la_h_sic = la_h_tpr / np.sqrt(la_h_fpr)

    # Idealised Classifier Outputs (Pre-CDOT)
    ideal_h_fpr, ideal_h_tpr, _ = roc_curve(test_df["signal"], test_df["ideal_h"])
    ideal_h_sic = ideal_h_tpr / np.sqrt(ideal_h_fpr)

    # Idealised Classifier Outputs (Post-CDOT)
    trans_ideal_h_fpr, trans_ideal_h_tpr, _ = roc_curve(test_df["signal"], test_df["trans_ideal_h"])
    trans_ideal_h_sic = trans_ideal_h_tpr / np.sqrt(trans_ideal_h_fpr)

    # Random Line
    random_tpr = np.linspace(0, 1, 300)
    random_sic = random_tpr / np.sqrt(random_tpr)
# Out:
# 198631

# %%
fig, axs = plt.subplots(1,2, figsize = (20,7))

axs[0].plot(h_tpr, h_sic, label="$h_{CATHODE}$", color = "fuchsia")
# axs[0].plot(inv_trans_h_tpr, inv_trans_h_sic, label="$T_W(h_{CATHODE})$", color = "black")
axs[0].plot(trans_h_tpr, trans_h_sic, label="$T_M(h_{CATHODE})$", color = "darkorange")

axs[0].plot(la_h_tpr, la_h_sic, label="$h_{LaCATHODE}$", color = "darkred")
axs[0].plot(ideal_h_tpr, ideal_h_sic, label = "$h_{supervised}$", color = "lawngreen")
axs[0].plot(trans_ideal_h_tpr, trans_ideal_h_sic, label = "$T_M(h_{supervised})$", color = "blue")
axs[0].plot(random_tpr, random_sic, "k:", label="random")
axs[0].set_xlabel("True Positive Rate (Signal Efficiency)", fontsize = 17)
axs[0].set_ylabel("Significance Improvement", fontsize = 17)
axs[0].set_title("SIC Curve", fontsize = 18, fontweight = "bold")

# Axis numbers font size
axs[0].tick_params(axis='x', labelsize=15)
axs[0].tick_params(axis='y', labelsize=15)


axs[1].plot(h_fpr, h_tpr, label="$h_{CATHODE}$", color = "fuchsia")
# axs[1].plot(inv_trans_h_fpr, inv_trans_h_tpr, label="$T_W(h_{CATHODE})$", color = "black")
axs[1].plot(trans_h_fpr, trans_h_tpr, label="$T_M(h_{CATHODE})$", color = "darkorange")

axs[1].plot(la_h_fpr, la_h_tpr, label="$h_{LaCATHODE}$", color = "darkred")
axs[1].plot(ideal_h_fpr, ideal_h_tpr, label = "$h_{supervised}$", color = "lawngreen")
axs[1].plot(trans_ideal_h_fpr, trans_ideal_h_tpr, label = "$T_M(h_{supervised})$", color = "blue")
axs[1].plot(random_tpr, random_tpr, "k:", label="random")
axs[1].set_xlabel("False Positive Rate (Background Efficiency)", fontsize = 17)
axs[1].set_ylabel("True Positive Rate (Signal Efficiency)", fontsize = 17)
axs[1].set_title("ROC Curve", fontsize = 18, fontweight = "bold")

# Axis numbers font size
axs[1].tick_params(axis='x', labelsize=15)
axs[1].tick_params(axis='y', labelsize=15)

h, l = axs[0].get_legend_handles_labels()     # Avoid repeats of legend, labels from 1st plot

fig.legend(h, l, loc="lower center", ncol = 3, prop={'size': 15})
fig.subplots_adjust(bottom = 0.225)

fig.savefig("SIC_ROC_W-tagging", bbox_inches = "tight")

plt.show()

# %%
fig, axs = plt.subplots(1,1, figsize = (10,7))

axs.plot(h_tpr, h_sic, label="$h_{CATHODE}$", color = "fuchsia")
# axs.plot(inv_trans_h_tpr, inv_trans_h_sic, label="$T_W(h_{CATHODE})$", color = "black")
axs.plot(trans_h_tpr, trans_h_sic, label="$T_M(h_{CATHODE})$", color = "darkorange")

axs.plot(la_h_tpr, la_h_sic, label="$h_{LaCATHODE}$", color = "darkred")
axs.plot(ideal_h_tpr, ideal_h_sic, label = "$h_{supervised}$", color = "lawngreen")
axs.plot(trans_ideal_h_tpr, trans_ideal_h_sic, label = "$T_M(h_{supervised})$", color = "blue")
axs.plot(random_tpr, random_sic, "k:", label="random")
axs.set_xlabel("True Positive Rate (Signal Efficiency)", fontsize = 17)
axs.set_ylabel("Significance Improvement", fontsize = 17)
axs.set_title("SIC Curve", fontsize = 18, fontweight = "bold")

fig.savefig("Example_SIC", bbox_inches = "tight")

plt.show()

# %%
fig, axs = plt.subplots(1,1, figsize = (10,7))

axs.plot(h_fpr, h_tpr, label="$h_{CATHODE}$", color = "fuchsia")
# axs.plot(inv_trans_h_fpr, inv_trans_h_tpr, label="$T_W(h_{CATHODE})$", color = "black")
axs.plot(trans_h_fpr, trans_h_tpr, label="$T_M(h_{CATHODE})$", color = "darkorange")

axs.plot(la_h_fpr, la_h_tpr, label="$h_{LaCATHODE}$", color = "darkred")
axs.plot(ideal_h_fpr, ideal_h_tpr, label = "$h_{supervised}$", color = "lawngreen")
axs.plot(trans_ideal_h_fpr, trans_ideal_h_tpr, label = "$T_M(h_{supervised})$", color = "blue")
axs.plot(random_tpr, random_tpr, "k:", label="random")
axs.set_xlabel("False Positive Rate (Background Efficiency)", fontsize = 17)
axs.set_ylabel("True Positive Rate (Signal Efficiency)", fontsize = 17)
axs.set_title("ROC Curve", fontsize = 18, fontweight = "bold")


fig.savefig("Example_ROC", bbox_inches = "tight")

plt.show()

# %%
# import numpy as np
# from scipy.spatial.distance import cdist

# def hhg_test_statistic(X, Y):
#     """
#     Fast vectorised HHG test statistic.

#     X : (N,p) array
#     Y : (N,q) array
#     """

#     X = np.asarray(X)
#     Y = np.asarray(Y)
#     N = X.shape[0]

#     Dx = cdist(X, X)
#     Dy = cdist(Y, Y)

#     T = 0.0

#     for i in range(N):

#         # Distances from point i
#         dx = Dx[i]
#         dy = Dy[i]

#         # Boolean comparison matrices
#         close_x = dx[:, None] <= dx[None, :]
#         close_y = dy[:, None] <= dy[None, :]

#         # Remove self comparisons
#         np.fill_diagonal(close_x, False)
#         np.fill_diagonal(close_y, False)

#         # Compute contingency counts
#         A11 = np.sum(close_x & close_y, axis=0)
#         A12 = np.sum(close_x & ~close_y, axis=0)
#         A21 = np.sum(~close_x & close_y, axis=0)
#         A22 = np.sum(~close_x & ~close_y, axis=0)

#         A1 = A11 + A12
#         A2 = A21 + A22
#         B1 = A11 + A21
#         B2 = A12 + A22

#         mask = (A1 > 0) & (A2 > 0) & (B1 > 0) & (B2 > 0)

#         S = np.zeros(N)
#         S[mask] = (N-2) * (A12[mask]*A21[mask] - A11[mask]*A22[mask])**2 / (
#             A1[mask]*A2[mask]*B1[mask]*B2[mask]
#         )

#         T += np.sum(S)

#     return T

# %%
# independence_test_statistic(test_df["h"].to_numpy().reshape(-1,1), test_df["mass"].to_numpy().reshape(-1,1))

# %%
# cutdata = test_df[test_df["trans_h"] > 0.85]

# hhg_test_statistic(cutdata["trans_h"].to_numpy().reshape(-1,1), cutdata["mass"].to_numpy().reshape(-1,1))

# %%
# import numpy as np
# from sklearn.metrics.pairwise import rbf_kernel

# def hsic_statistic(X, Y, sigma_x=None, sigma_y=None):
#     """
#     Compute the biased HSIC statistic.

#     Parameters
#     ----------
#     X : (n,d1) array
#     Y : (n,d2) array
#     sigma_x : kernel bandwidth for X
#     sigma_y : kernel bandwidth for Y

#     Returns
#     -------
#     hsic : float
#     """

#     n = X.shape[0]

#     # default bandwidth: median heuristic
#     if sigma_x is None:
#         pairwise_dists = np.linalg.norm(X[:,None] - X[None,:], axis=2)
#         sigma_x = np.median(pairwise_dists)

#     if sigma_y is None:
#         pairwise_dists = np.linalg.norm(Y[:,None] - Y[None,:], axis=2)
#         sigma_y = np.median(pairwise_dists)

#     # Kernel matrices
#     K = rbf_kernel(X, gamma=1/(2*sigma_x**2))
#     L = rbf_kernel(Y, gamma=1/(2*sigma_y**2))

#     # Centering matrix
#     H = np.eye(n) - np.ones((n,n))/n

#     # HSIC
#     hsic = np.trace(K @ H @ L @ H) / (n**2)

#     return hsic

# %%
# cutdata = test_df[test_df["trans_h"] > 0.85]

# hsic_statistic(cutdata["trans_h"].to_numpy(), cutdata["mass"].to_numpy())

# %%
# hsic_statistic(test_df["la_h"].to_numpy(), test_df["mass"].to_numpy())

# %%
n = 20
thresholds = np.linspace(0.1, 0.9, n)
classifiers = ("h", "trans_h", "la_h", "ideal_h", "trans_ideal_h")

# Shape: (n_classifiers, n_thresholds)
lambdas    = np.zeros((len(classifiers), n))
dist_corrs = np.zeros((len(classifiers), n))

for ci, h in enumerate(classifiers):
    scores = test_df[h].values
    signal = test_df["signal"].values
    mass   = test_df["mass"].values

    # Precompute all quantile cuts at once — shape (n,)
    quantile_cuts = np.quantile(scores, thresholds)

    # Sort once so threshold application becomes a simple slice
    sort_idx      = np.argsort(scores)
    sorted_scores = scores[sort_idx]
    sorted_signal = signal[sort_idx]
    sorted_mass   = mass[sort_idx]

    # Binary search to find cut index for each threshold — shape (n,)
    cut_indices = np.searchsorted(sorted_scores, quantile_cuts, side="left")

    for i, cut in enumerate(cut_indices):
        sig      = sorted_signal[cut:]
        mass_cut = sorted_mass[cut:]
        h_cut    = sorted_scores[cut:]

        n_sig = np.sum(sig == 1)
        n_bkg = np.sum(sig == 0)

        lambdas[ci, i]    = n_sig / n_bkg if n_bkg > 0 else np.nan
        dist_corrs[ci, i] = dcor.distance_correlation(h_cut, mass_cut, method = "avl")
# Out:
# /Users/hamzashah/anaconda3/envs/sk_cathode_env/lib/python3.10/site-packages/dcor/_fast_dcov_avl.py:554: UserWarning: Falling back to uncompiled AVL fast distance covariance terms because of TypeError exception raised: No matching definition for argument type(s) array(float32, 1d, C), array(float64, 1d, C), bool. Rembember: only floating point values can be used in the compiled implementations.
#   warnings.warn(

# %%
colours = ("fuchsia", "darkorange", "darkred", "lawngreen", "blue")
labels = (r"$h_{CATHODE}$", r"$T_M(h_{CATHODE})$", r"$h_{LaCATHODE}$", r"$h_{Supervised}$", r"$T_M(h_{Supervised})$")

# %%
fig, axs = plt.subplots(1,2, figsize = (20,7))

for i in range(len(classifiers)):
    axs[0].plot(lambdas[i], dist_corrs[i], color=colours[i], label=labels[i])

axs[0].set_xlabel("Signal-to-Background Ratio ($n_s/n_b$)", fontsize=15)
axs[0].set_ylabel("Distance Correlation", fontsize=15)
axs[0].set_title("Signal Enrichment vs Decorrelation", fontsize = 15, fontweight = "bold")

axs[1].plot(h_fpr, h_tpr, label="$h_{CATHODE}$", color = "fuchsia")
# axs[1].plot(inv_trans_h_fpr, inv_trans_h_tpr, label="$T_W(h_{CATHODE})$", color = "black")
axs[1].plot(trans_h_fpr, trans_h_tpr, label="$T_M(h_{CATHODE})$", color = "darkorange")

axs[1].plot(la_h_fpr, la_h_tpr, label="$h_{LaCATHODE}$", color = "darkred")
axs[1].plot(ideal_h_fpr, ideal_h_tpr, label = "$h_{supervised}$", color = "lawngreen")
axs[1].plot(trans_ideal_h_fpr, trans_ideal_h_tpr, label = "$T_M(h_{supervised})$", color = "blue")
axs[1].plot(random_tpr, random_tpr, "k:", label="random")

axs[1].set_xlabel("False Positive Rate (Background Efficiency)", fontsize = 15)
axs[1].set_ylabel("True Positive Rate (Signal Efficiency)", fontsize = 15)
axs[1].set_title("ROC Curve", fontsize = 15, fontweight = "bold")

h, l = axs[1].get_legend_handles_labels()     # Avoid repeats of legend, labels from 1st plot

fig.legend(h, l, loc="lower center", ncol = 2, prop={'size': 11})
fig.subplots_adjust(bottom = 0.2)

fig.savefig("DisCo_ROC_Correlated", bbox_inches = "tight")

plt.show()

# %%
colours = ("fuchsia", "darkorange", "darkred", "lawngreen", "blue")
labels = (r"$h_{CATHODE}$", r"$T_M(h_{CATHODE})$", r"$h_{LaCATHODE}$", r"$h_{Supervised}$", r"$T_M(h_{Supervised})$")


fig, ax = plt.subplots(figsize=(8, 4))

for i in range(len(classifiers)):
    ax.plot(lambdas[i], dist_corrs[i], color=colours[i], label=labels[i])

fig.legend(
    loc="lower center",
    ncol=len(classifiers),
    fontsize=10,
)

ax.set_xlabel("Signal-to-Background Ratio $(n_s/n_b)$", fontsize=10)
ax.set_ylabel("Distance Correlation", fontsize=10)
plt.tight_layout()
plt.subplots_adjust(bottom=0.215)

plt.savefig("Lambda_Correlation_W-tagging")

plt.show()

# %%
colours = ("fuchsia", "darkorange", "darkred", "lawngreen", "blue")
labels = ("CATHODE", "CATHODE+CDOT", "LaCATHODE", "Supervised", "Supervised+CDOT")

fig, ax = plt.subplots(figsize=(7, 4))

for i in range(len(classifiers)):
    ax.plot(thresholds, dist_corrs[i], color=colours[i], label=labels[i])

fig.legend(
    loc="lower center",
    ncol=len(classifiers),
    fontsize=8,
)
ax.set_xlabel("Threshold", fontsize=10)
ax.set_ylabel("Distance Correlation", fontsize=10)
plt.tight_layout()
plt.subplots_adjust(bottom=0.2)

plt.savefig("Threshold_Correlation_W-tagging")
plt.show()
